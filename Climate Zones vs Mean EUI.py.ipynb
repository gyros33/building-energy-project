# %%
# Dependencies and Setup
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mp

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('climate_dataframe.csv')
# df1= pd.read_csv('Data/bpd_data.csv')
# df2 = pd.read_csv('Data/weather_data.csv')

# %%
df1=df.drop([7])
df1
# Out:
#     count                                group        mean  percentile_0  \
# 0    4985      6A Cold - Humid (Burlington-VT)  224.309992      1.595628
# 1    4769         4C Mixed - Marine (Salem-OR)  211.742252      3.153924
# 2      12           8 Subarctic (Fairbanks-AK)  269.417620     89.286969
# 3     594      4B Mixed - Dry (Albuquerque-NM)  258.339404      3.201754
# 4   12320           3B Warm - Dry (El Paso-TX)  248.297527      1.870980
# 5     658              7 Very Cold (Duluth-MN)  221.686867      4.762470
# 6   24547      4A Mixed - Humid (Baltimore-MD)  247.678112      1.283320
# 8    4551             5B Cool - Dry (Boise-ID)  249.417662      2.570411
# 9     599            6B Cold - Dry (Helena-MT)  235.887173      6.692308
# 10  19581         5A Cool - Humid (Chicago-IL)  265.943118      2.084757
# 11   9118         3A Warm - Humid (Memphis-TN)  278.237605      2.938462
# 12   6674          2A Hot - Humid (Houston-TX)  265.201748      1.738035
# ...

# %%
climate_zone = ['Cold_Humid', 'Mixed_Marine', 'Subarctic', 'Mixed_Dry', 'Warm_Dry', 'Very_Cold', 'Mixed_Humid', 'Unknown', 'Cool_Dry', 'Cold_Dry', 'Cool_Humid', 'Warm_Humid', 'Hot_Humid', 'Hot_Dry', 'Warm_Marine', 'Vhot_Humid']

city_state = ['Burlington_VT', 'Salem_OR', 'Fairbanks_AK', 'Albuquerque_NM', 'ElPaso_TX', 'Duluth_MN', 'Baltimor_MD', 'Unknown', 'Boise_ID', 'Helena_MT', 'Chicago_Il', 'Memphis_TN', 'Houston_TX', 'Phoenix_AZ', 'SanFrancisco_CA', 'Miami_FL']

mean = [224.309992, 211.742252, 269.417620, 258.339404, 248.297527, 221.686867, 247.678112, 467.501375, 249.417662, 235.887173, 265.943118, 278.237605, 265.201748, 241.053986, 228.149300, 248.66224]

# index = ['Cold_Humid', 'Mixed_Marine', 'Subarctic', 'Mixed_Dry', 'Warm_Dry', 'Very_Cold', 'Mixed_Humid', 'Unknown', 'Cool_Dry', 'Cold_Dry', 'Cool_Humid', 'Warm_Humid', 'Hot_Humid', 'Hot_Dry', 'Warm_Marine', 'Vhot_Humid']

x=np.arange(16)

Plot=df1.plot.bar(y='mean', color=['black', 'green', 'red', 'blue', 'yellow', 'orange', 'purple', 'indigo', 'lime', 'orangered', 'pink', 'violet', 'aqua', 'maroon', 'olive', 'limegreen'])
plt.xticks(x,('Cold_Humid', 'Mixed_Marine', 'Subarctic', 'Mixed_Dry', 'Warm_Dry', 'Very_Cold', 'Mixed_Humid', 'Unknown', 'Cool_Dry', 'Cold_Dry', 'Cool_Humid', 'Warm_Humid', 'Hot_Humid', 'Hot_Dry', 'Warm_Marine', 'Vhot_Humid'))
plt.title("Climate Zones vs. Mean EUI")
plt.xlabel("Climate Zones")
plt.ylabel("Mean EUI")
plt.legend()
plt.savefig('Climate_Zones_vs_Mean(EUI)')
